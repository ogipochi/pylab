# %%
from keras.layers import Dense,Activation,SimpleRNN
from keras.models import Sequential
import numpy as np
import codecs
# Out:
# Using TensorFlow backend.

# %%
# データは

# ファイルの読み込み
INPUT_FILE = "./data/alice_in_wonderland.txt"
with codecs.open(INPUT_FILE,"r",encoding="utf-8") as f:
    lines = []
    # すべての行について空の行でなければ
    # その行の端の空白を削除して小文字にしたものをlinesリストに追加
    for line in f:
        if len(line)!=0:
            lines.append(line.strip().lower())
text = " ".join(lines)

# %%
# textに出てくるすべての文字を集合で取得
chars = set(text)
nb_chars = len(chars)

# すべての文字列について索引を作成する
char2index = dict()
index2char = dict()
for i,c in enumerate(chars):
    char2index[c] = i
    index2char[i] = c

# %%
# 試しに文字からidを取得してみる
id_c = char2index["c"]
print(id_c)
#本当に正しいIDか確認
char_c = index2char[id_c]
print(char_c)
# Out:
# 55
# c

# %%
SEQLEN = 10
STEP   = 1

input_chars = []
label_chars = []
for i in range(0,len(text) - SEQLEN , STEP):
    input_chars.append(text[i:i+SEQLEN])  # i~i+SEQLEN-1番目のSEQLENの文字数テキストを取得
    label_chars.append(text[i + SEQLEN])  # SEQLEN番目のi文字のテキストを取得

# %%
# 入力、出力データをone-hotラベル化する

# まずは０で初期化した行列を作成する
X = np.zeros((len(input_chars),SEQLEN,nb_chars),dtype=np.bool)
y = np.zeros((len(input_chars),nb_chars),dtype=np.bool)

# 入力すべてのデータについて文字からidを取得しその列の値だけ1にする
for i , input_char in enumerate(input_chars):
    for j,ch in enumerate(input_char):
        X[i,j,char2index[ch]] = 1
    # その時の正解データの文字を取得しそこからidを取得しその列の値を1にする
    label_char = label_chars[i]
    y[i,char2index[label_char]] = 1

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 128
NUM_ITERATIONS = 25
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100

# %%
model = Sequential()
model.add(SimpleRNN(
    HIDDEN_SIZE,
    return_sequences=False,
    input_shape=(SEQLEN,nb_chars),
    unroll=True
))
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy",optimizer="rmsprop")

# %%
for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: {}".format(iteration))
    model.fit(X,y,batch_size=BATCH_SIZE,epochs=NUM_EPOCHS_PER_ITERATION)
    
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]
    print("Generationg from seed: {}".format(test_chars))
    print(test_chars,end="")
    
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest = np.zeros((1,SEQLEN,nb_chars))
        for j,ch in enumerate(test_chars):
            Xtest[0,j,char2index[ch]] = 1
        
        pred = model.predict(Xtest,verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print(ypred,end="")
        test_chars = test_chars[1:] + ypred
    print()
# Out:
# ==================================================
# Iteration #: 0
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 2.3775
# Generationg from seed: of all thi
# of all thin the the the the the the the the the the the the the the the the the the the the the the the the th
# ==================================================
# Iteration #: 1
# Epoch 1/1
# 162739/162739 [==============================] - 4s 24us/step - loss: 2.0670
# Generationg from seed:  tortoise,
#  tortoise, and the groplone the mast on the said the groplone the mast on the said the groplone the mast on th
# ==================================================
# Iteration #: 2
# Epoch 1/1
# 162739/162739 [==============================] - 4s 24us/step - loss: 1.9639
# Generationg from seed: k. she pit
# k. she pither all as in the wast of the southen the wast of the southen the wast of the southen the wast of th
# ==================================================
# Iteration #: 3
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.8853
# Generationg from seed: use this e
# use this eree say she said the say her she seat the cat on the the the her her her her her her her her her her
# ==================================================
# Iteration #: 4
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.8191
# Generationg from seed:  very unea
#  very uneas and the sere har seat and the mouse the mouse the mouse the mouse the mouse the mouse the mouse th
# ==================================================
# Iteration #: 5
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.7638
# Generationg from seed: ‘i keep th
# ‘i keep the could be the looked and the morken the more the more the more the more the more the more the more
# ==================================================
# Iteration #: 6
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.7166
# Generationg from seed: foot slipp
# foot slippone the was so the was to the was to the was to the was to the was to the was to the was to the was
# ==================================================
# Iteration #: 7
# Epoch 1/1
# 162739/162739 [==============================] - 4s 24us/step - loss: 1.6767
# Generationg from seed: d round th
# d round the gryphon and the gryphon and the gryphon and the gryphon and the gryphon and the gryphon and the gr
# ==================================================
# Iteration #: 8
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.6424
# Generationg from seed: ar that do
# ar that do work of the poor at the poor at the poor at the poor at the poor at the poor at the poor at the poo
# ==================================================
# Iteration #: 9
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.6118
# Generationg from seed: hose twelv
# hose twelver the project gutenberg-tm electronic work of the project gutenberg-tm electronic work of the proje
# ==================================================
# Iteration #: 10
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.5857
# Generationg from seed: ing.  ‘nea
# ing.  ‘nears of the hatter was sor the rabbit and the hatter was sor the rabbit and the hatter was sor the rab
# ==================================================
# Iteration #: 11
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.5626
# Generationg from seed:  mind,’ sa
#  mind,’ said alice, and the same beanter a crowing and looked and her all was the same beanter a crowing and l
# ==================================================
# Iteration #: 12
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.5416
# Generationg from seed: ring of fo
# ring of for the thought to herself to the first it at all the more sures it was the was to herself to the firs
# ==================================================
# Iteration #: 13
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.5235
# Generationg from seed: eir forepa
# eir forepation and the project gutenberg-tm all the parse she had not and the project gutenberg-tm all the par
# ==================================================
# Iteration #: 14
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.5073
# Generationg from seed: th in para
# th in paragrop of the court, as she was to herself to the project gutenberg litely to the project gutenberg li
# ==================================================
# Iteration #: 15
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.4924
# Generationg from seed: entures in
# entures in a long and she thing you know the rabbit her she went on the they well as she was to she was sood t
# ==================================================
# Iteration #: 16
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.4793
# Generationg from seed:  it was ju
#  it was just a little good not it was the parse is the door alice was the could not it was the parse is the do
# ==================================================
# Iteration #: 17
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.4667
# Generationg from seed: e of the l
# e of the looked to the white rabbit had betting at the course the searly and alice was seemed to her feet the
# ==================================================
# Iteration #: 18
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.4558
# Generationg from seed: s not at a
# s not at alice should fin the mouse was a project gutenberg-tm little thing it her any project gutenberg-tm li
# ==================================================
# Iteration #: 19
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.4456
# Generationg from seed: ce.  ‘come
# ce.  ‘come or a grown out of the some of the course in the project gutenberg-tm like the same the hatter was a
# ==================================================
# Iteration #: 20
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.4362
# Generationg from seed: e the conv
# e the conversed the dormouse done a good the dormouse done a good the dormouse done a good the dormouse done a
# ==================================================
# Iteration #: 21
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.4266
# Generationg from seed: k pie-crus
# k pie-crusted in the seating the mock turtle so mady a little and before the court a little and before the cou
# ==================================================
# Iteration #: 22
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.4202
# Generationg from seed: at by the
# at by the histlend her had her had her had her had her had her had her had her had her had her had her had her
# ==================================================
# Iteration #: 23
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.4115
# Generationg from seed: ng cheated
# ng cheated at the works of the soment the same the seage of the work of the soment the same the seage of the w
# ==================================================
# Iteration #: 24
# Epoch 1/1
# 162739/162739 [==============================] - 4s 25us/step - loss: 1.4055
# Generationg from seed: folded her
# folded her head looking and she was think i can like the serms of this agreement was a little thing in a grown
